# %% [markdown]
# <a href="https://colab.research.google.com/github/shivusuhas149-web/Embedded-C/blob/master/EDA_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# impoort python libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv('/content/Diwali Sales Data.csv',encoding='unicode_escape')

# %%
df.shape # rows X col.
# Out:
# (11251, 15)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
#drop unrelated/blank columns
df.drop(['Status','unnamed1'],axis=1,inplace=True) # .drop,axis=1,inplace=True

# %%
#check for null values
pd.isnull(df).sum() # .isnull(df).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
#drop null values
df.dropna(inplace=True)

# %%
# change data type
df['Amount'] = df['Amount'].astype('int') # .astype('int)

# %%
df['Amount'].dtypes # .dtypes
# Out:
# dtype('int64')

# %%
df.columns # .columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#rename colunm
df.rename(columns={'Marital_Status':'Marriage'}) # .rename
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marriage  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28         0
# 1      1000732       Kartik  P00110942      F     26-35   35         1
# 2      1001990        Bindu  P00118542      F     26-35   35         1
# 3      1001425       Sudevi  P00237842      M      0-17   16         0
# 4      1000588         Joni  P00057942      M     26-35   28         1
# ...        ...          ...        ...    ...       ...  ...       ...
# 11246  1000695      Manning  P00296942      M     18-25   19         1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33         0
# 11248  1001209        Oshin  P00201342      F     36-45   40         0
# 11249  1004023       Noonan  P00059442      M     36-45   37         0
# 11250  1002744      Brumley  P00281742      F     18-25   19         0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
df.describe() #.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# use describe() for specific columns
df[['Age','Orders','Amount']].describe() # .describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
# Exploratory Data Analysis = EDA

# %%
import seaborn as sns
ax=sns.countplot(x='Gender',data=df)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for gender vs total amount
sales_gen = df.groupby(['Gender'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x = 'Gender',y = 'Amount',data = sales_gen)
# Out:
# <Axes: xlabel='Gender', ylabel='Amount'>

# %%
import seaborn as sns
# plotting a bar chart for Age Group and its count
ax = sns.countplot(data = df,x = 'Age Group',hue = 'Gender')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# plotting a bar chart for total number of top 10 states
sales_state = df.groupby(['State'],as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
ax = sns.barplot(x = 'State',y = 'Amount',data = sales_state)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data =df,x='Product_Category')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
ax = sns.countplot(data=df, x='Occupation', order=df['Occupation'].value_counts().index)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Count of Customers by Occupation')
plt.xlabel('Occupation')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

orders_by_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
ax = sns.barplot(x = 'State', y = 'Orders', data = orders_by_state)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Total Number of Orders in Top 10 States')
plt.xlabel('State')
plt.ylabel('Total Orders')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
display(sales_state)
# Out:
#                State    Amount
# 14     Uttar Pradesh  19374968
# 10       Maharashtra  14427543
# 7          Karnataka  13523540
# 2              Delhi  11603818
# 9     Madhya Pradesh   8101142
# 0     Andhra Pradesh   8037146
# 5   Himachal Pradesh   4963368
# 4            Haryana   4220175
# 1              Bihar   4022757
# 3            Gujarat   3946082

# %%
orders_by_user = df.groupby(['User_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False)
display(orders_by_user)
# Out:
#       User_ID  Orders
# 1045  1001680      58
# 2134  1003476      57
# 2355  1003808      55
# 3748  1006036      52
# 1197  1001941      52
# ...       ...     ...
# 963   1001540       1
# 1509  1002458       1
# 1505  1002454       1
# 3685  1005942       1
# 818   1001311       1
#
# [3752 rows x 2 columns]

# %%
display(orders_by_state)
# Out:
#                State  Orders
# 14     Uttar Pradesh    4807
# 10       Maharashtra    3810
# 7          Karnataka    3240
# 2              Delhi    2740
# 9     Madhya Pradesh    2252
# 0     Andhra Pradesh    2051
# 5   Himachal Pradesh    1568
# 8             Kerala    1137
# 4            Haryana    1109
# 3            Gujarat    1066

# %%
orders_by_user = df.groupby(['User_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False)
display(orders_by_user.head(10))
# Out:
#       User_ID  Orders
# 1045  1001680      58
# 2134  1003476      57
# 2355  1003808      55
# 3748  1006036      52
# 1197  1001941      52
# 2897  1004682      51
# 2916  1004725      50
# 1628  1002665      50
# 274   1000424      48
# 2741  1004425      48

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
ax = sns.countplot(data=df, x='Marital_Status', hue='Gender')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Marital Status Distribution by Gender')
plt.xlabel('Marital Status (0 = Unmarried, 1 = Married)')
plt.ylabel('Number of Customers')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

top_10_users = orders_by_user.head(10)
sns.set(rc={'figure.figsize':(15,5)})
ax = sns.barplot(x='User_ID', y='Orders', data=top_10_users)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Top 10 Users by Number of Orders')
plt.xlabel('User ID')
plt.ylabel('Total Orders')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sales_gen = df.groupby(['Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(8,5)})
ax = sns.barplot(x='Gender', y='Amount', data=sales_gen)

for bars in ax.containers:
    ax.bar_label(bars)

plt.title('Total Sales Amount by Gender')
plt.xlabel('Gender')
plt.ylabel('Total Sales Amount')
plt.show()

# %%
orders_by_user_ascending = orders_by_user.sort_values(by='Orders', ascending=True)
display(orders_by_user_ascending.head(10))
# Out:
#       User_ID  Orders
# 471   1000750       1
# 477   1000759       1
# 2964  1004800       1
# 39    1000064       1
# 45    1000076       1
# 1210  1001964       1
# 0     1000001       1
# 3332  1005377       1
# 2115  1003452       1
# 2116  1003453       1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 7))
ax = sns.countplot(data=df, x='Occupation', hue='Gender', order=df['Occupation'].value_counts().index)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Occupation Distribution by Gender')
plt.xlabel('Occupation')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sales_by_product_category = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

plt.figure(figsize=(15, 7))
ax = sns.barplot(x='Product_Category', y='Amount', data=sales_by_product_category)
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Total Sales Amount by Product Category')
plt.xlabel('Product Category')
plt.ylabel('Total Sales Amount')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
display(sales_by_product_category)
# Out:
#          Product_Category    Amount
# 6                    Food  33933883
# 3      Clothing & Apparel  16495019
# 5   Electronics & Gadgets  15643846
# 7        Footwear & Shoes  15575209
# 8               Furniture   5440051
# 9            Games & Toys   4331694
# 14        Sports Products   3635933
# 1                  Beauty   1959484
# 0                    Auto   1958609
# 15             Stationery   1676051
# 11        Household items   1569337
# 16             Tupperware   1155642
# 2                   Books   1061478
# 4                   Decor    730360
# 13               Pet Care    482277
# 10     Hand & Power Tools    405618
# 17             Veterinary    112702
# 12                 Office     81936

# %%
display(orders_by_user_ascending)
# Out:
#       User_ID  Orders
# 471   1000750       1
# 477   1000759       1
# 2964  1004800       1
# 39    1000064       1
# 45    1000076       1
# ...       ...     ...
# 1197  1001941      52
# 3748  1006036      52
# 2355  1003808      55
# 2134  1003476      57
# 1045  1001680      58
#
# [3752 rows x 2 columns]

# %%
amount_by_user = df.groupby(['User_ID'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
display(amount_by_user)
# Out:
#       User_ID  Amount
# 1045  1001680  281034
# 1197  1001941  239147
# 2134  1003476  220435
# 1628  1002665  201104
# 2355  1003808  197660
# ...       ...     ...
# 2215  1003606     582
# 2647  1004268     580
# 965   1001542     574
# 2713  1004378     572
# 3253  1005258     567
#
# [3752 rows x 2 columns]

# %%
amount_by_user = df.groupby(['User_ID'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)
display(amount_by_user.head(10))
# Out:
#       User_ID  Amount
# 1045  1001680  281034
# 1197  1001941  239147
# 2134  1003476  220435
# 1628  1002665  201104
# 2355  1003808  197660
# 2741  1004425  194343
# 2226  1003618  189921
# 274   1000424  187679
# 2897  1004682  185122
# 807   1001298  184045

# %%
user_id_to_find = 1001680
cust_name = df[df['User_ID'] == user_id_to_find]['Cust_name'].iloc[0]
print(f"The customer name for User_ID {user_id_to_find} is: {cust_name}")
# Out:
# The customer name for User_ID 1001680 is: Vasudev

# %%
lowest_amount_user = amount_by_user.sort_values(by='Amount', ascending=True).head(1)
display(lowest_amount_user)
# Out:
#       User_ID  Amount
# 3253  1005258     567

# %%
user_id_to_find = 1005258
cust_name = df[df['User_ID'] == user_id_to_find]['Cust_name'].iloc[0]
print(f"The customer name for User_ID {user_id_to_find} is: {cust_name}")
# Out:
# The customer name for User_ID 1005258 is: Aromal

# %%
user_zone = df[df['User_ID'] == user_id_to_find]['Zone']
display(user_zone)
# Out:
# 11230    Central
# Name: Zone, dtype: object

# %%
zone_counts = df['Zone'].value_counts()
display(zone_counts)
# Out:
# Zone
# Central     4289
# Southern    2693
# Western     1952
# Northern    1491
# Eastern      814
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
ax = sns.barplot(x=zone_counts.index, y=zone_counts.values, palette='viridis')
for bars in ax.containers:
    ax.bar_label(bars)
plt.title('Distribution of Sales Zones')
plt.xlabel('Zone')
plt.ylabel('Number of Customers')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_595/2791599081.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=zone_counts.index, y=zone_counts.values, palette='viridis')

# %%
#Age
ax = sns.countplot(data =df,x='Age Group', hue ='Gender')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Toatl amount vs Age group
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
sns.barplot(x = 'Age Group',y= 'Amount',data = sales_age)
# Out:
# <Axes: xlabel='Age Group', ylabel='Amount'>

# %%
#status
# total number of orders from top 10 states
sales_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders')
sns.set(rc = {'figure.figsize':(20,5)})
ax = sns.barplot(data = sales_state, x = 'State',y ='Orders')

# %%
# total amount/sales from top 10 states
sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount')
sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'State',y ='Amount')
# Out:
# <Axes: xlabel='State', ylabel='Amount'>

# %%
# Marital status
ax = sns.countplot(data =df, x = 'Marital_Status')
sns.set(rc={'figure.figsize':(7,5)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_statw = df.groupby(['Marital_Status','Gender'])

# %%
# Occupation
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data =df, x = 'Occupation')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Product category
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.countplot(data =df, x = 'Product_Category')
for bars in ax.containers:
    ax.bar_label(bars)
#

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.barplot(data = sales_state, x = 'Product_ID',y ='Orders')

# %%
sales_state = df.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False).head(10)
sns.set(rc={'figure.figsize':(20,5)})
ax = sns.barplot(data = sales_state, x = 'Product_Category',y ='Amount')

# %%
# top 10 most sold products (same thing as above)
Fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>

# %%
# products (same thing as above)
Fig1, ax1 = plt.subplots(figsize=(12,7))
df.groupby('Product_ID')['Orders'].sum().nlargest(10).sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Product_ID'>
